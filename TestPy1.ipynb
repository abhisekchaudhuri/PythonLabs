# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisekchaudhuri/PythonLabs/blob/Learning-Python/TestPy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name= input('what is your name?')
print("Hello", name )

age=input("how old are you?")
print(name,"age is",age)
print("in next ten years you will be",int(age)+10)
# Out:
# what is your name?ABhisek
# Hello ABhisek
# how old are you?46
# ABhisek age is 46
# in next ten years you will be 56
